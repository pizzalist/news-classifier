# %%
import pandas as pd

# %%
df = pd.read_csv('./clipped_news_1128.csv')
df
# Out:
#                                                 title  \
# 0                AI 반도체 ETF '후끈'…동시 상장 5일만에 1500억 몰렸다
# 1                            [블록체인 칼럼]금융샌드박스와 네거티브 규제
# 2      '보안체계 강화' 센트비, 글로벌 표준 정보보호∙개인정보 경영시스템 인증 동시 취득
# 3              사슬 블록체인 컨퍼런스 성료, 3세대 블록체인 기술과 미래 전망 논의
# 4                비투엔, 실버케어에서 '응급 케어'로 AI 의료 서비스 사업 확장
# ...                                               ...
# 1500                           700억이상 공공SW, 대기업 참여 허용
# 1501  "800억 공사업체 바꾸는 게 말이 되나"…카카오 C레벨의  폭로전, 대체 무슨 일?
# 1502        [위기의 행정망, 해법은]〈2〉전수 조사후 노후설비 교체주기 새로 정립해야
# 1503         '통풍 날개를 태양광으로' LX하우시스, 건물일체형 태양광발전시스템 개발
# 1504                               미래 건물, 이 굴착기가 만듭니다
#
#                                                     url  topic_idx  news_date
# 0     https://n.news.naver.com/mnews/article/011/000...          0   20231128
# 1     https://n.news.naver.com/mnews/article/030/000...          0   20231128
# 2     https://n.news.naver.com/mnews/article/014/000...          0   20231128
# ...

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=False)

# %%
df.to_csv('./clipped_news_1128.csv', index=False)

# %%
df
# Out:
#                                                 title  \
# 0                AI 반도체 ETF '후끈'…동시 상장 5일만에 1500억 몰렸다
# 1                            [블록체인 칼럼]금융샌드박스와 네거티브 규제
# 2      '보안체계 강화' 센트비, 글로벌 표준 정보보호∙개인정보 경영시스템 인증 동시 취득
# 3              사슬 블록체인 컨퍼런스 성료, 3세대 블록체인 기술과 미래 전망 논의
# 4                비투엔, 실버케어에서 '응급 케어'로 AI 의료 서비스 사업 확장
# ...                                               ...
# 1499  "800억 공사업체 바꾸는 게 말이 되나"…카카오 C레벨의  폭로전, 대체 무슨 일?
# 1500                           700억이상 공공SW, 대기업 참여 허용
# 1502        [위기의 행정망, 해법은]〈2〉전수 조사후 노후설비 교체주기 새로 정립해야
# 1503         '통풍 날개를 태양광으로' LX하우시스, 건물일체형 태양광발전시스템 개발
# 1504                               미래 건물, 이 굴착기가 만듭니다
#
#                                                     url  topic_idx  news_date
# 0     https://n.news.naver.com/mnews/article/011/000...          0   20231128
# 1     https://n.news.naver.com/mnews/article/030/000...          0   20231128
# 2     https://n.news.naver.com/mnews/article/014/000...          0   20231128
# ...
